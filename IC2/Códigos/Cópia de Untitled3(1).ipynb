# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/foto.jpg')

# %%
print(img)
# Out:
# [[[ 14  30  23]
#   [ 14  30  23]
#   [ 14  30  23]
#   ...
#   [236 250 249]
#   [236 250 249]
#   [236 250 249]]
#
#  [[ 14  30  23]
#   [ 14  30  23]
#   [ 14  30  23]
#   ...
#   [236 250 249]
#   [236 250 249]
#   [236 250 249]]
#
#  [[ 14  30  23]
#   [ 14  30  23]
#   [ 15  31  24]
#   ...
#   [236 250 249]
#   [236 250 249]
#   [236 250 249]]
#
#  ...
#
#  [[ 13  14  12]
#   [ 11  14  12]
#   [ 11  14  12]
#   ...
#   [ 14  17  15]
#   [ 14  17  15]
#   [ 14  17  15]]
#
#  [[ 11  14  12]
#   [ 11  14  12]
#   [ 11  14  12]
#   ...
#   [ 14  17  15]
#   [ 14  17  15]
#   [ 14  17  15]]
#
#  [[ 11  14  12]
#   [ 11  14  12]
#   [ 11  14  12]
#   ...
#   [ 14  17  15]
#   [ 14  17  15]
#   [ 14  17  15]]]

# %%
plt.imshow(img)
plt.show()
